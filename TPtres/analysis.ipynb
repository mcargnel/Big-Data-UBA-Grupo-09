# %%
import pandas as pd

# %%
import json

# Esta es la ruta a tu archivo
file_path = '/Users/mcargnel/Documents/mea/Big-Data-UBA-Grupo-001/TP3/data/fraud/train_fraud_labels.json'

    # 1. Abre el archivo en modo lectura ('r')
with open(file_path, 'r') as file:
        
    data = json.load(file)

# %%
df_target = pd.DataFrame.from_dict(data['target'], orient='index', columns=['Target']).reset_index()

# %%
df_target
# Out:
#             index Target
# 0        10649266     No
# 1        23410063     No
# 2         9316588     No
# 3        12478022     No
# 4         9558530     No
# ...           ...    ...
# 8914958  14064699     No
# 8914959   7676538     No
# 8914960  15131030     No
# 8914961  17244732     No
# 8914962  15151926     No
#
# [8914963 rows x 2 columns]
